# %% [markdown]
# Question 2: Using the Scikit-Learn implementation of GaussianMixture on a 2D non- spherical dataset (e.g., the "Aniso" dataset):
# 1) Fit four different GMM models using the following covariance_type parameters: 'spherical', 'diag', 'tied', and 'full'.
# 2) For each type, plot the resulting cluster ellipses (2-standard deviation contours).
# 3) Explain which covariance type provides the best fit for elongated, tilted data clusters and why the spherical type fails in this scenario.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs


X, _ = make_blobs(n_samples=500, centers=3, random_state=42)

# Make anisotropic
X = np.dot(X, [[0.6, -0.6], [0.4, 0.8]])

#types = ['spherical', 'diag', 'tied', 'full']

for t in types:
    gmm = GaussianMixture(n_components=3, covariance_type=t)
    gmm.fit(X)
    labels = gmm.predict(X)

    plt.scatter(X[:,0], X[:,1], c=labels)
    plt.title(t)
    plt.show()
