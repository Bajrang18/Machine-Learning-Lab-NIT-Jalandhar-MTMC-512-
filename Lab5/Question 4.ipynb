# %% [markdown]
# ## Question 4: Algorithms have "geometric biases." K-Means assumes clusters are spherical and roughly equal in size.
# * ### Task: Apply both K-Means (with 𝑘 = 2) and DBSCAN to a "crescent moon" shaped dataset.
# * ### The Question: Based on your visualization, why does K-Means fail to capture the two distinct moon shapes while DBSCAN succeeds? In your own words, explain the difference between centroid-based clustering and density-based clustering.

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

X, y_true = make_moons(n_samples=300, noise=0.05, random_state=42)

plt.scatter(X[:,0], X[:,1])
plt.title("Moons Dataset")
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=42)
labels_kmeans = kmeans.fit_predict(X)

plt.scatter(X[:,0], X[:,1], c=labels_kmeans, cmap='viridis')
plt.title("K-Means Clustering")
plt.show()

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.2, min_samples=5)
labels_db = dbscan.fit_predict(X)

plt.scatter(X[:,0], X[:,1], c=labels_db, cmap='viridis')
plt.title("DBSCAN Clustering")
plt.show()

# %% [markdown]
# ## K-Means fails on the moons dataset because it assumes spherical clusters and minimizes distance to centroids. Since the moons dataset contains curved clusters, K-Means incorrectly partitions the data. DBSCAN successfully detects the clusters because it groups points based on density and does not assume any particular cluster shape.
