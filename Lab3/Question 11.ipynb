# %% [markdown]
# 11. Question 11: Pick a real-world dataset (e.g., Pima Indians Diabetes or Digits).
# *  Task: Implement k-NN, Decision Trees, Perceptron, and SVM. Perform a 5-fold cross- validation for each and create a table comparing:
# 1. Average Accuracy
# 2. Training Time
# 3. Prediction Speed (Latency)
# • Discussion: Which model would you choose if you needed a model that makes
# predictions in microseconds? Which would you choose if interpretability (explaining
# why a choice was made) was the top priority?

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import numpy as np
import time

wine = load_wine()
X, y = wine.data, wine.target

# %%
models = {
    "kNN": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "SVM": SVC(kernel="linear")
}

# %%
results = {}

for name, model in models.items():

    start = time.time()

    scores = cross_val_score(
        model,
        X,
        y,
        cv=5,
        scoring="accuracy"
    )

    end = time.time()

    results[name] = {
        "Mean Accuracy": np.mean(scores),
        "Std Dev": np.std(scores),
        "Time Taken": end - start
    }

# %%
for model, res in results.items():
    print(f"\n{model}")
    print("Mean Accuracy:", res["Mean Accuracy"])
    print("Std Dev:", res["Std Dev"])
    print("Training Time:", res["Time Taken"])
# Out:
# kNN
# Mean Accuracy: 0.6912698412698413
# Std Dev: 0.04877951071049148
# Training Time: 0.03136086463928223
#
# Decision Tree
# Mean Accuracy: 0.8653968253968254
# Std Dev: 0.04403610603149111
# Training Time: 0.009579896926879883
#
# Random Forest
# Mean Accuracy: 0.9720634920634922
# Std Dev: 0.017571077268107502
# Training Time: 0.41528773307800293
#
# SVM
# Mean Accuracy: 0.961111111111111
# Std Dev: 0.041573970964154924
# Training Time: 0.28757810592651367
