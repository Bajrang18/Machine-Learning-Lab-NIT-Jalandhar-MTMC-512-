# %% [markdown]
# ### 13. Given two DataFrames (load the datasets or create dummy), df_A and df_B, return only the rows present in df_A that are not present in df_B.

# %%
import pandas as pd
df = pd.DataFrame({
    'Category': ['A', 'A', 'B', 'B'],
    'Sales': [100, None, 200, None]
})

result = df_A.merge(df_B, how='left', indicator=True)
result = result[result['_merge'] == 'left_only'].drop('_merge', axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       1 import pandas as pd
#       2 df = pd.DataFrame({
#       3     'Category': ['A', 'A', 'B', 'B'],
#       4     'Sales': [100, None, 200, None]
#       5 })
# ----> 7 result = df_A.merge(df_B, how='left', indicator=True)
#       8 result = result[result['_merge'] == 'left_only'].drop('_merge', axis=1)
#
# NameError: name 'df_A' is not defined
