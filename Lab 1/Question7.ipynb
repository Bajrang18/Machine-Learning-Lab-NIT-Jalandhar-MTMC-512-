# %% [markdown]
# ### 7. Generate a random 5 × 10 matrix. Subtract the mean of each row from every element in that respective row using NumPy broadcasting.

# %%
import numpy as np
arr = np.random.rand(5,10)
row_mean = arr.mean(axis = 1, keepdims = True)
result = arr - row_mean
result
# Out:
# array([[ 0.13926119, -0.39163891,  0.14179897, -0.13629689, -0.32311736,
#          0.44807231,  0.46116236, -0.43437223,  0.42300136, -0.3278708 ],
#        [-0.16965152,  0.03538327, -0.35581058,  0.48674657,  0.28231018,
#          0.43669641, -0.21867455, -0.15450768, -0.20438853, -0.13810357],
#        [ 0.3418461 , -0.44190879,  0.09246249,  0.12138589,  0.10306409,
#         -0.0069419 , -0.03018433,  0.41030396, -0.46960096, -0.12042655],
#        [-0.08441737, -0.30897489, -0.43543725,  0.30853622,  0.30103903,
#         -0.26019683, -0.27382792,  0.2299515 ,  0.10874978,  0.41457772],
#        [ 0.09053095,  0.28474548, -0.38959107,  0.22494107, -0.3030104 ,
#          0.41234108, -0.35792029,  0.08782396,  0.14204752, -0.1919083 ]])
